# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this sci‑fi setting, the capital of The Moon is Selene Prime.
#
# - Location: A crescent city tucked into the rim of Shackleton Crater at the Moon’s southern pole, built to access permanently shadowed regions for water ice and to catch the rare sunlight on solar harvesters.
# - Government: The Ring Council governs from the Beacon Spire, the central political tower. Representatives come from the three habitat rings that form the city’s backbone.
# - Cityscape: A series of concentric rings—Core (political heart), Market Ring (industry and trade), and Habitat Ring (residence and culture)—linked by gravity bridges and vacuum tunnels. Glass-and-basalt architecture, with greenhouses and public parks suspended above the lunar dust.
# - Economy: Helium-3 refining, water ice extraction, biotech in closed-loop domes, and solar energy exports to Earth and other colonies.
# - Culture: A bilingual Lunar-Creed culture (Lunese and English-based creoles), festivals tied to rare sunlight and lunar eclipses, and a strong tradition of technocratic storytelling.
# - Landmarks: The Beacon Spire (seat of government), the Ice Archive (frozen records and data vaults), the Sea Gate (ice-port for shipments), and the Garden of Polaris (a biodome with hardy lunar flora).
# - Motto: “Under shadow we shine.”
#
# If you want, I can tailor Selene Prime further—its politics, culture, or a key event unfolding there.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ()

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 import base64
#       3 # Get the first (and only) uploaded file dict
# ----> 4 uploaded_file = uploader.value[0]
#       6 # This is a memoryview
#       7 content_mv = uploaded_file["content"]
#
# IndexError: tuple index out of range

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import sounddevice as sd
#       2 from scipy.io.wavfile import write
#       3 import base64
#
# ModuleNotFoundError: No module named 'sounddevice'

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       1 agent = create_agent(
#       2     model='gpt-4o-audio-preview',
#       3 )
#       5 multimodal_question = HumanMessage(content=[
#       6     {"type": "text", "text": "Tell me about this audio file"},
# ----> 7     {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
#       8 ])
#      10 response = agent.invoke(
#      11     {"messages": [multimodal_question]}
#      12 )
#      14 print(response['messages'][-1].content)
#
# NameError: name 'aud_b64' is not defined
