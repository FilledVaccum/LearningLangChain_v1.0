# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # No Memory

# %%
from langchain.agents import create_agent

agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content = "Hello My Name is FilledVaccum, and my favorite color is Black.")

response = agent.invoke(
    { "messages" : [question] }
)

# %%
from pprint import pprint
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello My Name is FilledVaccum, and my favorite color is Black.', additional_kwargs={}, response_metadata={}, id='4cfe0026-a3e7-445d-aed6-fc9f933b5826'),
#               AIMessage(content='Nice to meet you, FilledVaccum. Black is a great, timeless choice—sleek and versatile.\n\nWhat would you like to do today? I can help with questions, brainstorm ideas, write or edit something, explain a topic, or work on a project. Tell me a bit about your interests or what you’re working on, and we’ll take it from there.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 661, 'prompt_tokens': 21, 'total_tokens': 682, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CwYIDyP11UcrhYkgQHMLxSlEr5rFv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ba93c-9d7e-7691-9c9e-16a494caf9b3-0', usage_metadata={'input_tokens': 21, 'output_tokens': 661, 'total_tokens': 682, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}

# %%
question = HumanMessage(content="What's my favorite color?")

response = agent.invoke(
    { "messages" : [question] }
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favorite color?", additional_kwargs={}, response_metadata={}, id='eccf2252-cec9-48dd-b698-16a72c30fa24'),
#               AIMessage(content='I don’t know your favorite color yet. I don’t have access to your preferences.\n\nIf you’d like a guess: blue is a very common favorite.\n\nWant a quick, personalized guess? Answer a few short questions or tell me 3 colors you like and I’ll pick one that fits. For example:\n- Do you prefer cool colors (blue/green/purple) or warm colors (red/orange/yellow)?\n- Do you like bright, saturated colors or muted tones?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1388, 'prompt_tokens': 11, 'total_tokens': 1399, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1280, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CwYJWo7XQwbwmSeedrbAYwbhcYLfq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ba93d-d748-7563-86e9-1b7e8289545b-0', usage_metadata={'input_tokens': 11, 'output_tokens': 1388, 'total_tokens': 1399, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1280}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    checkpointer=InMemorySaver(),
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content = "Hello My Name is FilledVaccum and my fav color is Black?")

config = { "configurable" : {"thread_id" : "1"} }

response = agent.invoke(
    {"messages": [question] },
    config,
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello My Name is FilledVaccum and my fav color is Black?', additional_kwargs={}, response_metadata={}, id='f811f5f5-6645-4f54-aab8-375a4d41e3c8'),
#               AIMessage(content='Nice to meet you, FilledVaccum! Black is a bold, versatile favorite.\n\nWhat would you like to chat about or do next? Here are a few ideas:\n- Design ideas using black (UI, logos, posters)\n- Fashion/style tips with black outfits\n- Color palettes that pair well with black\n- Fun facts about black in culture or art\n- Quick color codes or how to implement dark mode\n\nTell me your interest and I’ll tailor it.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 679, 'prompt_tokens': 20, 'total_tokens': 699, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CwYUINMeCD0WJEj27ILXjkOheJqst', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ba948-0c69-7970-a57d-af7884853b36-0', usage_metadata={'input_tokens': 20, 'output_tokens': 679, 'total_tokens': 699, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}

# %%
question = HumanMessage(content="What is my favorite color?")

response = agent.invoke(
    { "messages" : [question] },
    config,
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello My Name is FilledVaccum and my fav color is Black?', additional_kwargs={}, response_metadata={}, id='f811f5f5-6645-4f54-aab8-375a4d41e3c8'),
#               AIMessage(content='Nice to meet you, FilledVaccum! Black is a bold, versatile favorite.\n\nWhat would you like to chat about or do next? Here are a few ideas:\n- Design ideas using black (UI, logos, posters)\n- Fashion/style tips with black outfits\n- Color palettes that pair well with black\n- Fun facts about black in culture or art\n- Quick color codes or how to implement dark mode\n\nTell me your interest and I’ll tailor it.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 679, 'prompt_tokens': 20, 'total_tokens': 699, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CwYUINMeCD0WJEj27ILXjkOheJqst', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ba948-0c69-7970-a57d-af7884853b36-0', usage_metadata={'input_tokens': 20, 'output_tokens': 679, 'total_tokens': 699, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#               HumanMessage(content='What is my favorite color?', additional_kwargs={}, response_metadata={}, id='8bc87ab8-9d92-40fc-88b0-d317a28ffd5c'),
#               AIMessage(content='Your favorite color is Black. Want ideas for using black in design, fashion, or palettes?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 156, 'prompt_tokens': 130, 'total_tokens': 286, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CwYVe4AHjGO2vayfCm9rgB7atEkI7', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ba949-56e1-7983-a3c1-abcfe2af07e9-0', usage_metadata={'input_tokens': 130, 'output_tokens': 156, 'total_tokens': 286, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]}
